# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("32_Murder_victim_age_sex.csv")
df.head()
# Out:
#                    Area_Name  Year               Group_Name  \
# 0  Andaman & Nicobar Islands  2001  Murder - Female Victims
# 1             Andhra Pradesh  2001  Murder - Female Victims
# 2          Arunachal Pradesh  2001  Murder - Female Victims
# 3                      Assam  2001  Murder - Female Victims
# 4                      Bihar  2001  Murder - Female Victims
#
#       Sub_Group_Name  Victims_Above_50_Yrs  Victims_Total  \
# 0  2. Female Victims                   NaN              6
# 1  2. Female Victims                  67.0            607
# 2  2. Female Victims                   2.0             16
# 3  2. Female Victims                  11.0            128
# 4  2. Female Victims                  12.0            366
#
#    Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  \
# 0                     NaN                  NaN                     NaN
# 1                    15.0                 38.0                    43.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area_Name               1018 non-null   object
#  1   Year                    1018 non-null   int64
#  2   Group_Name              1018 non-null   object
#  3   Sub_Group_Name          1018 non-null   object
#  4   Victims_Above_50_Yrs    962 non-null    float64
#  5   Victims_Total           1018 non-null   int64
#  6   Victims_Upto_10_15_Yrs  876 non-null    float64
#  7   Victims_Upto_10_Yrs     900 non-null    float64
#  8   Victims_Upto_15_18_Yrs  888 non-null    float64
#  9   Victims_Upto_18_30_Yrs  1009 non-null   float64
#  10  Victims_Upto_30_50_Yrs  1007 non-null   float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 87.6+ KB

# %%
areaname_encodings={
   "Andaman & Nicobar Islands":0,
    "Andhra Pradesh":1,
    "Arunachal Pradesh":2,
    "Assam":3,
    "Bihar":4,
    "Chandigarh":5,
    "Chhattisgarh":6,
    "Delhi":7,
    "Goa":8,
    "Gujarat":9,
    "Haryana":10,
    "Himachal Pradesh":11,
    "Jammu & Kashmir":12,
    "Jharkhand":13,
    "Karnataka":14,
    "Kerala":15,
    "Lakshadweep":16,
    "Madhya Pradesh":17,
    "Maharashtra":18,
    "Manipur":19,
    "Meghalaya":20,
    "Mizoram":21,
    "Nagaland":22,
    "Odisha":23,
    "Puducherry":24,
    "Punjab":25,
    "Rajasthan":26,
    "Sikkim":27,
    "Tamil Nadu":28,
    "Tripura":29,
    "Uttar Pradesh":30,
    "Uttarakhand":31,
    "West Bengal":32,
    "Dadra & Nagar Haveli":33,
    "Daman & Diu":34
}
areaname_encode_dict={
    'Area_Name': areaname_encodings,
}
df.replace(areaname_encode_dict, inplace=True)

# %%
df.head()
# Out:
#    Area_Name  Year               Group_Name     Sub_Group_Name  \
# 0          0  2001  Murder - Female Victims  2. Female Victims
# 1          1  2001  Murder - Female Victims  2. Female Victims
# 2          2  2001  Murder - Female Victims  2. Female Victims
# 3          3  2001  Murder - Female Victims  2. Female Victims
# 4          4  2001  Murder - Female Victims  2. Female Victims
#
#    Victims_Above_50_Yrs  Victims_Total  Victims_Upto_10_15_Yrs  \
# 0                   NaN              6                     NaN
# 1                  67.0            607                    15.0
# 2                   2.0             16                     0.0
# 3                  11.0            128                     8.0
# 4                  12.0            366                     0.0
#
#    Victims_Upto_10_Yrs  Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  \
# 0                  NaN                     NaN                     4.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder
ftr_list=['Group_Name','Sub_Group_Name']
encoder=LabelEncoder()
for ftr in ftr_list:
    df[ftr]=encoder.fit_transform(df[ftr])
    print(encoder.classes_)
# Out:
# ['Murder - Female Victims' 'Murder - Male Victims'
#  'Murder - Total Victims']
# ['1. Male Victims' '2. Female Victims' '3. Total']

# %%
df.head(30)
# Out:
#     Area_Name  Year  Group_Name  Sub_Group_Name  Victims_Above_50_Yrs  \
# 0           0  2001           0               1                   NaN
# 1           1  2001           0               1                  67.0
# 2           2  2001           0               1                   2.0
# 3           3  2001           0               1                  11.0
# 4           4  2001           0               1                  12.0
# 5           5  2001           0               1                   3.0
# 6           6  2001           0               1                  63.0
# 7           7  2001           0               1                  14.0
# 8           8  2001           0               1                   1.0
# 9           9  2001           0               1                  26.0
# 10         10  2001           0               1                   6.0
# 11         11  2001           0               1                   6.0
# ...

# %%
#df=df.fillna(method="ffill")
#df=df.fillna(method="bfill")
#df.head()

# %%
df["Victims_Upto_10_Yrs"]=df["Victims_Upto_10_Yrs"].fillna(df["Victims_Upto_10_Yrs"].mean())
df["Victims_Upto_10_15_Yrs"]=df["Victims_Upto_10_15_Yrs"].fillna(df["Victims_Upto_10_15_Yrs"].mean())
df["Victims_Upto_15_18_Yrs"]=df["Victims_Upto_15_18_Yrs"].fillna(df["Victims_Upto_15_18_Yrs"].mean())
df["Victims_Upto_18_30_Yrs"]=df["Victims_Upto_18_30_Yrs"].fillna(df["Victims_Upto_18_30_Yrs"].mean())
df["Victims_Upto_30_50_Yrs"]=df["Victims_Upto_30_50_Yrs"].fillna(df["Victims_Upto_30_50_Yrs"].mean())
df["Victims_Above_50_Yrs"]=df["Victims_Above_50_Yrs"].fillna(df["Victims_Above_50_Yrs"].mean())
df
# Out:
#       Area_Name  Year  Group_Name  Sub_Group_Name  Victims_Above_50_Yrs  \
# 0             0  2001           0               1             67.559252
# 1             1  2001           0               1             67.000000
# 2             2  2001           0               1              2.000000
# 3             3  2001           0               1             11.000000
# 4             4  2001           0               1             12.000000
# ...         ...   ...         ...             ...                   ...
# 1013         28  2010           2               2            327.000000
# 1014         29  2010           2               2             24.000000
# 1015         30  2010           2               2            344.000000
# 1016         31  2010           2               2             19.000000
# 1017         32  2010           2               2            120.000000
#
#       Victims_Total  Victims_Upto_10_15_Yrs  Victims_Upto_10_Yrs  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area_Name               1018 non-null   int64
#  1   Year                    1018 non-null   int64
#  2   Group_Name              1018 non-null   int32
#  3   Sub_Group_Name          1018 non-null   int32
#  4   Victims_Above_50_Yrs    1018 non-null   float64
#  5   Victims_Total           1018 non-null   int64
#  6   Victims_Upto_10_15_Yrs  1018 non-null   float64
#  7   Victims_Upto_10_Yrs     1018 non-null   float64
#  8   Victims_Upto_15_18_Yrs  1018 non-null   float64
#  9   Victims_Upto_18_30_Yrs  1018 non-null   float64
#  10  Victims_Upto_30_50_Yrs  1018 non-null   float64
# dtypes: float64(6), int32(2), int64(3)
# memory usage: 79.7 KB

# %%
df=df[['Area_Name','Year','Group_Name','Victims_Upto_10_15_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs','Victims_Above_50_Yrs','Victims_Total']]
df.head()
# Out:
#    Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 0          0  2001           0                 9.53653
# 1          1  2001           0                15.00000
# 2          2  2001           0                 0.00000
# 3          3  2001           0                 8.00000
# 4          4  2001           0                 0.00000
#
#    Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 0               17.326577                     4.0                     2.0
# 1               43.000000                   269.0                   175.0
# 2                0.000000                    10.0                     4.0
# 3               23.000000                    45.0                    37.0
# 4               40.000000                   191.0                   123.0
#
#    Victims_Above_50_Yrs  Victims_Total
# 0             67.559252              6
# 1             67.000000            607
# 2              2.000000             16
# ...

# %%
df.shape
# Out:
# (1018, 9)

# %% [markdown]
# # outlier detection

# %%
from sklearn import linear_model
import seaborn as sb
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # victims 10-15 years

# %%
df['Victims_Upto_10_15_Yrs'].describe()
# Out:
# count    1018.000000
# mean        9.536530
# std        19.865819
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%         9.536530
# max       218.000000
# Name: Victims_Upto_10_15_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Upto_10_15_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_10_15_Yrs'>

# %%
Q1 = df.Victims_Upto_10_15_Yrs.quantile(0.25)
Q3 = df.Victims_Upto_10_15_Yrs.quantile(0.75)
Q1,Q3
# Out:
# (0.0, 9.536529680365296)

# %%
IQR= Q3-Q1
IQR
# Out:
# 9.536529680365296

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (-14.304794520547944, 23.841324200913242)

# %%
df[df['Victims_Upto_10_15_Yrs']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Area_Name, Year, Group_Name, Victims_Upto_10_15_Yrs, Victims_Upto_15_18_Yrs, Victims_Upto_18_30_Yrs, Victims_Upto_30_50_Yrs, Victims_Above_50_Yrs, Victims_Total]
# Index: []

# %%
df[df['Victims_Upto_10_15_Yrs']>upper_limit]
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 18           18  2001           0                    28.0
# 30           30  2001           0                    65.0
# 44            9  2002           0                    25.0
# 52           18  2002           0                    27.0
# 63           30  2002           0                    57.0
# ...         ...   ...         ...                     ...
# 985           1  2010           2                    28.0
# 988           4  2010           2                    44.0
# 1002         17  2010           2                    40.0
# 1003         18  2010           2                    34.0
# 1015         30  2010           2                    82.0
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 18                      41.0                   555.0                   290.0
# 30                     103.0                   626.0                   417.0
# ...

# %%
new_df=df[(df.Victims_Upto_10_15_Yrs>lower_limit)&(df.Victims_Upto_10_15_Yrs<upper_limit)]
new_df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 0             0  2001           0                 9.53653
# 1             1  2001           0                15.00000
# 2             2  2001           0                 0.00000
# 3             3  2001           0                 8.00000
# 4             4  2001           0                 0.00000
# ...         ...   ...         ...                     ...
# 1012         27  2010           2                 1.00000
# 1013         28  2010           2                13.00000
# 1014         29  2010           2                 2.00000
# 1016         31  2010           2                 1.00000
# 1017         32  2010           2                 8.00000
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 0                  17.326577                     4.0                     2.0
# 1                  43.000000                   269.0                   175.0
# ...

# %%
df['Victims_Upto_10_15_Yrs']=np.where(df['Victims_Upto_10_15_Yrs']>=upper_limit,upper_limit,np.where(df['Victims_Upto_10_15_Yrs']<=lower_limit,lower_limit,df['Victims_Upto_10_15_Yrs']))

# %%
sb.boxplot(df["Victims_Upto_10_15_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_10_15_Yrs'>

# %%
df.shape
# Out:
# (1018, 9)

# %%
df['Victims_Upto_10_15_Yrs'].describe()
# Out:
# count    1018.000000
# mean        6.699427
# std         7.349336
# min         0.000000
# 25%         0.000000
# 50%         4.000000
# 75%         9.536530
# max        23.841324
# Name: Victims_Upto_10_15_Yrs, dtype: float64

# %% [markdown]
# # Victims_Upto_15_18_Yrs

# %%
df['Victims_Upto_15_18_Yrs'].describe()
# Out:
# count    1018.000000
# mean       17.326577
# std        36.886566
# min         0.000000
# 25%         1.000000
# 50%         5.000000
# 75%        17.326577
# max       347.000000
# Name: Victims_Upto_15_18_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Upto_15_18_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_15_18_Yrs'>

# %%
Q1 = df.Victims_Upto_15_18_Yrs.quantile(0.25)
Q3 = df.Victims_Upto_15_18_Yrs.quantile(0.75)
Q1,Q3
# Out:
# (1.0, 17.326576576576578)

# %%
IQR= Q3-Q1
IQR
# Out:
# 16.326576576576578

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (-23.489864864864867, 41.81644144144144)

# %%
df[df['Victims_Upto_15_18_Yrs']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Area_Name, Year, Group_Name, Victims_Upto_10_15_Yrs, Victims_Upto_15_18_Yrs, Victims_Upto_18_30_Yrs, Victims_Upto_30_50_Yrs, Victims_Above_50_Yrs, Victims_Total]
# Index: []

# %%
df[df['Victims_Upto_15_18_Yrs']>upper_limit]
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 1             1  2001           0               15.000000
# 28           28  2001           0                8.000000
# 30           30  2001           0               23.841324
# 63           30  2002           0               23.841324
# 97           30  2003           0               23.841324
# ...         ...   ...         ...                     ...
# 988           4  2010           2               23.841324
# 990           6  2010           2               13.000000
# 1002         17  2010           2               23.841324
# 1011         26  2010           2               22.000000
# 1015         30  2010           2               23.841324
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 1                       43.0                   269.0                   175.0
# 28                     113.0                   174.0                   191.0
# ...

# %%
new_df=df[(df.Victims_Upto_15_18_Yrs>lower_limit)&(df.Victims_Upto_15_18_Yrs<upper_limit)]
new_df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 0             0  2001           0                 9.53653
# 2             2  2001           0                 0.00000
# 3             3  2001           0                 8.00000
# 4             4  2001           0                 0.00000
# 5             5  2001           0                 0.00000
# ...         ...   ...         ...                     ...
# 1012         27  2010           2                 1.00000
# 1013         28  2010           2                13.00000
# 1014         29  2010           2                 2.00000
# 1016         31  2010           2                 1.00000
# 1017         32  2010           2                 8.00000
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 0                  17.326577                     4.0                     2.0
# 2                   0.000000                    10.0                     4.0
# ...

# %%
df['Victims_Upto_15_18_Yrs']=np.where(df['Victims_Upto_15_18_Yrs']>=upper_limit,upper_limit,np.where(df['Victims_Upto_15_18_Yrs']<=lower_limit,lower_limit,df['Victims_Upto_15_18_Yrs']))

# %%
df['Victims_Upto_15_18_Yrs'].describe()
# Out:
# count    1018.000000
# mean       11.189243
# std        13.328326
# min         0.000000
# 25%         1.000000
# 50%         5.000000
# 75%        17.326577
# max        41.816441
# Name: Victims_Upto_15_18_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Upto_15_18_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_15_18_Yrs'>

# %%
df.shape
# Out:
# (1018, 9)

# %% [markdown]
# # Victims_Upto_18_30_Yrs

# %%
df['Victims_Upto_18_30_Yrs'].describe()
# Out:
# count    1018.000000
# mean      314.739346
# std       481.600197
# min         0.000000
# 25%        13.000000
# 50%       117.500000
# 75%       415.750000
# max      3724.000000
# Name: Victims_Upto_18_30_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Upto_18_30_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_18_30_Yrs'>

# %%
Q1 = df.Victims_Upto_18_30_Yrs.quantile(0.25)
Q3 = df.Victims_Upto_18_30_Yrs.quantile(0.75)
Q1,Q3
# Out:
# (13.0, 415.75)

# %%
IQR= Q3-Q1
IQR
# Out:
# 402.75

# %%
lower_limit = Q1-1.5*IQR
upper_limit = Q3+1.5*IQR
lower_limit, upper_limit
# Out:
# (-591.125, 1019.875)

# %%
df[df['Victims_Upto_18_30_Yrs']<lower_limit]
# Out:
# Empty DataFrame
# Columns: [Area_Name, Year, Group_Name, Victims_Upto_10_15_Yrs, Victims_Upto_15_18_Yrs, Victims_Upto_18_30_Yrs, Victims_Upto_30_50_Yrs, Victims_Above_50_Yrs, Victims_Total]
# Index: []

# %%
df[df['Victims_Upto_18_30_Yrs']>upper_limit]
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 341           4  2001           1                2.000000
# 367          30  2001           1               23.841324
# 374           4  2002           1                3.000000
# 401          30  2002           1               23.841324
# 408           4  2003           1                2.000000
# ...         ...   ...         ...                     ...
# 988           4  2010           2               23.841324
# 999          13  2010           2                2.000000
# 1003         18  2010           2               23.841324
# 1015         30  2010           2               23.841324
# 1017         32  2010           2                8.000000
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 341                41.816441                  1484.0                  1406.0
# 367                41.816441                  3098.0                  2726.0
# ...

# %%
new_df=df[(df['Victims_Upto_18_30_Yrs']<upper_limit) & (df['Victims_Upto_18_30_Yrs']>lower_limit)]
new_df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 0             0  2001           0                 9.53653
# 1             1  2001           0                15.00000
# 2             2  2001           0                 0.00000
# 3             3  2001           0                 8.00000
# 4             4  2001           0                 0.00000
# ...         ...   ...         ...                     ...
# 1011         26  2010           2                22.00000
# 1012         27  2010           2                 1.00000
# 1013         28  2010           2                13.00000
# 1014         29  2010           2                 2.00000
# 1016         31  2010           2                 1.00000
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 0                  17.326577                     4.0                     2.0
# 1                  41.816441                   269.0                   175.0
# ...

# %%
df['Victims_Upto_18_30_Yrs']=np.where(df['Victims_Upto_18_30_Yrs']>=upper_limit,upper_limit,np.where(df['Victims_Upto_18_30_Yrs']<=lower_limit,lower_limit,df['Victims_Upto_18_30_Yrs']))

# %%
df['Victims_Upto_18_30_Yrs'].describe()
# Out:
# count    1018.000000
# mean      266.007273
# std       312.640955
# min         0.000000
# 25%        13.000000
# 50%       117.500000
# 75%       415.750000
# max      1019.875000
# Name: Victims_Upto_18_30_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Upto_18_30_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_18_30_Yrs'>

# %%
df.shape
# Out:
# (1018, 9)

# %% [markdown]
# # Victims_Upto_30_50_Yrs

# %%
df['Victims_Upto_30_50_Yrs'].describe()
# Out:
# count    1018.000000
# mean      274.230387
# std       394.058414
# min         0.000000
# 25%        13.000000
# 50%       105.000000
# 75%       409.750000
# max      3143.000000
# Name: Victims_Upto_30_50_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Upto_30_50_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_30_50_Yrs'>

# %%
upper_limit=df['Victims_Upto_30_50_Yrs'].quantile(0.9)
upper_limit
# Out:
# 764.6000000000008

# %%
lower_limit=df['Victims_Upto_30_50_Yrs'].quantile(0.1)
lower_limit
# Out:
# 3.0

# %%
new_df=df[(df['Victims_Upto_30_50_Yrs']<upper_limit) & (df['Victims_Upto_30_50_Yrs']>lower_limit)]
new_df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 1             1  2001           0                    15.0
# 2             2  2001           0                     0.0
# 3             3  2001           0                     8.0
# 4             4  2001           0                     0.0
# 6             6  2001           0                    14.0
# ...         ...   ...         ...                     ...
# 1010         25  2010           2                     9.0
# 1011         26  2010           2                    22.0
# 1012         27  2010           2                     1.0
# 1014         29  2010           2                     2.0
# 1016         31  2010           2                     1.0
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 1                  41.816441                   269.0                   175.0
# 2                   0.000000                    10.0                     4.0
# ...

# %%
df['Victims_Upto_30_50_Yrs'].describe()
# Out:
# count    1018.000000
# mean      274.230387
# std       394.058414
# min         0.000000
# 25%        13.000000
# 50%       105.000000
# 75%       409.750000
# max      3143.000000
# Name: Victims_Upto_30_50_Yrs, dtype: float64

# %%
df['Victims_Upto_30_50_Yrs']=np.where(df['Victims_Upto_30_50_Yrs']>=upper_limit,upper_limit,np.where(df['Victims_Upto_30_50_Yrs']<=lower_limit,lower_limit,df['Victims_Upto_30_50_Yrs']))

# %%
sb.boxplot(new_df["Victims_Upto_30_50_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Upto_30_50_Yrs'>

# %%
df.shape
# Out:
# (1018, 9)

# %% [markdown]
# # Victims_Above_50_Yrs

# %%
df['Victims_Above_50_Yrs'].describe()
# Out:
# count    1018.000000
# mean       67.559252
# std        97.840011
# min         0.000000
# 25%         3.250000
# 50%        29.000000
# 75%        82.000000
# max       824.000000
# Name: Victims_Above_50_Yrs, dtype: float64

# %%
sb.boxplot(df["Victims_Above_50_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Above_50_Yrs'>

# %%
upper_limit=df['Victims_Above_50_Yrs'].quantile(0.85)
upper_limit
# Out:
# 131.0

# %%
lower_limit=df['Victims_Above_50_Yrs'].quantile(0.15)
lower_limit
# Out:
# 2.0

# %%
new_df=df[(df['Victims_Above_50_Yrs']<upper_limit) & (df['Victims_Above_50_Yrs']>lower_limit)]
new_df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 0             0  2001           0                 9.53653
# 1             1  2001           0                15.00000
# 3             3  2001           0                 8.00000
# 4             4  2001           0                 0.00000
# 5             5  2001           0                 0.00000
# ...         ...   ...         ...                     ...
# 1010         25  2010           2                 9.00000
# 1012         27  2010           2                 1.00000
# 1014         29  2010           2                 2.00000
# 1016         31  2010           2                 1.00000
# 1017         32  2010           2                 8.00000
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 0                  17.326577                   4.000                     3.0
# 1                  41.816441                 269.000                   175.0
# ...

# %%
df['Victims_Above_50_Yrs']=np.where(df['Victims_Above_50_Yrs']>=upper_limit,upper_limit,np.where(df['Victims_Above_50_Yrs']<=lower_limit,lower_limit,df['Victims_Above_50_Yrs']))

# %%
df['Victims_Above_50_Yrs'].describe()
# Out:
# count    1018.000000
# mean       48.466914
# std        47.667251
# min         2.000000
# 25%         3.250000
# 50%        29.000000
# 75%        82.000000
# max       131.000000
# Name: Victims_Above_50_Yrs, dtype: float64

# %%
sb.boxplot(new_df["Victims_Above_50_Yrs"])
# Out:
# <AxesSubplot:xlabel='Victims_Above_50_Yrs'>

# %%
df.shape
# Out:
# (1018, 9)

# %% [markdown]
# # Victims_Total

# %%
df['Victims_Total'].describe()
# Out:
# count    1018.000000
# mean      683.406680
# std      1015.595667
# min         0.000000
# 25%        31.000000
# 50%       258.000000
# 75%      1011.750000
# max      8180.000000
# Name: Victims_Total, dtype: float64

# %%
sb.boxplot(df["Victims_Total"])
# Out:
# <AxesSubplot:xlabel='Victims_Total'>

# %%
upper_limit=df['Victims_Total'].quantile(0.9)
upper_limit
# Out:
# 1781.4000000000005

# %%
lower_limit=df['Victims_Total'].quantile(0.1)
lower_limit
# Out:
# 7.0

# %%
new_df=df[(df['Victims_Total']<upper_limit) & (df['Victims_Total']>lower_limit)]
new_df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 1             1  2001           0                    15.0
# 2             2  2001           0                     0.0
# 3             3  2001           0                     8.0
# 4             4  2001           0                     0.0
# 6             6  2001           0                    14.0
# ...         ...   ...         ...                     ...
# 1010         25  2010           2                     9.0
# 1011         26  2010           2                    22.0
# 1012         27  2010           2                     1.0
# 1014         29  2010           2                     2.0
# 1016         31  2010           2                     1.0
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 1                  41.816441                   269.0                   175.0
# 2                   0.000000                    10.0                     4.0
# ...

# %%
df['Victims_Total']=np.where(df['Victims_Total']>=upper_limit,upper_limit,np.where(df['Victims_Total']<=lower_limit,lower_limit,df['Victims_Total']))

# %%
df['Victims_Total'].describe()
# Out:
# count    1018.000000
# mean      553.886837
# std       616.286118
# min         7.000000
# 25%        31.000000
# 50%       258.000000
# 75%      1011.750000
# max      1781.400000
# Name: Victims_Total, dtype: float64

# %%
sb.boxplot(new_df["Victims_Total"])
# Out:
# <AxesSubplot:xlabel='Victims_Total'>

# %%
df.shape
# Out:
# (1018, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1018 entries, 0 to 1017
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Area_Name               1018 non-null   int64
#  1   Year                    1018 non-null   int64
#  2   Group_Name              1018 non-null   int32
#  3   Victims_Upto_10_15_Yrs  1018 non-null   float64
#  4   Victims_Upto_15_18_Yrs  1018 non-null   float64
#  5   Victims_Upto_18_30_Yrs  1018 non-null   float64
#  6   Victims_Upto_30_50_Yrs  1018 non-null   float64
#  7   Victims_Above_50_Yrs    1018 non-null   float64
#  8   Victims_Total           1018 non-null   float64
# dtypes: float64(6), int32(1), int64(2)
# memory usage: 67.7 KB

# %%
sb.boxplot(df["Year"])  # No outliers in "Year" column
# Out:
# <AxesSubplot:xlabel='Year'>

# %% [markdown]
# # training and testing

# %%
X=df.drop(columns=['Victims_Upto_10_15_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs','Victims_Above_50_Yrs','Victims_Total'])

# %%
X
# Out:
#       Area_Name  Year  Group_Name
# 0             0  2001           0
# 1             1  2001           0
# 2             2  2001           0
# 3             3  2001           0
# 4             4  2001           0
# ...         ...   ...         ...
# 1013         28  2010           2
# 1014         29  2010           2
# 1015         30  2010           2
# 1016         31  2010           2
# 1017         32  2010           2
#
# [1018 rows x 3 columns]

# %%
Y=df.drop(columns=['Area_Name','Year','Group_Name','Victims_Total'])

# %%
Y
# Out:
#       Victims_Upto_10_15_Yrs  Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  \
# 0                   9.536530               17.326577                   4.000
# 1                  15.000000               41.816441                 269.000
# 2                   0.000000                0.000000                  10.000
# 3                   8.000000               23.000000                  45.000
# 4                   0.000000               40.000000                 191.000
# ...                      ...                     ...                     ...
# 1013               13.000000               16.000000                 650.000
# 1014                2.000000                0.000000                  60.000
# 1015               23.841324               41.816441                1019.875
# 1016                1.000000                2.000000                  91.000
# 1017                8.000000                6.000000                1019.875
#
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
X_train
# Out:
#      Area_Name  Year  Group_Name
# 368         31  2001           1
# 258         21  2008           0
# 282         10  2009           0
# 179         10  2006           0
# 437         32  2003           1
# ..         ...   ...         ...
# 535         28  2006           1
# 499         26  2005           1
# 331         27  2010           0
# 564         23  2007           1
# 343          6  2001           1
#
# [814 rows x 3 columns]

# %%
Y_train
# Out:
#      Victims_Upto_10_15_Yrs  Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  \
# 368                     3.0                3.000000                    52.0
# 258                     0.0                0.000000                     1.0
# 282                     2.0                2.000000                    96.0
# 179                     1.0                2.000000                    90.0
# 437                     0.0                2.000000                   606.0
# ..                      ...                     ...                     ...
# 535                     7.0                2.000000                   286.0
# 499                     7.0               16.000000                   399.0
# 331                     1.0               17.326577                     3.0
# 564                    10.0               11.000000                   395.0
# 343                    12.0               30.000000                   341.0
#
#      Victims_Upto_30_50_Yrs  Victims_Above_50_Yrs
# ...

# %%
X_test
# Out:
#       Area_Name  Year  Group_Name
# 295          24  2009           0
# 483           9  2005           1
# 817           5  2005           2
# 128          27  2004           0
# 302          31  2009           0
# ...         ...   ...         ...
# 727          15  2002           2
# 411          33  2003           1
# 1004         19  2010           2
# 874          26  2006           2
# 615          33  2009           1
#
# [204 rows x 3 columns]

# %%
Y_test
# Out:
#       Victims_Upto_10_15_Yrs  Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  \
# 295                  9.53653               17.326577                     3.0
# 483                  9.00000               10.000000                   293.0
# 817                  0.00000                0.000000                     7.0
# 128                  0.00000                0.000000                     2.0
# 302                  1.00000               17.326577                    38.0
# ...                      ...                     ...                     ...
# 727                  9.00000                7.000000                   118.0
# 411                  9.53653               17.326577                     3.0
# 1004                 2.00000                0.000000                    31.0
# 874                 22.00000               25.000000                   505.0
# 615                  9.53653               17.326577                     1.0
#
# ...

# %%
from sklearn.linear_model import LinearRegression

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,Y_train) # Training our model
# Out:
# LinearRegression()

# %%
reg.predict(X_train)
# Out:
# array([[  6.73718143,  12.12959322, 248.41626671, 223.19845933,
#          45.52768106],
#        [  5.38814655,   8.46057682, 146.49235574, 129.3551428 ,
#          33.33557849],
#        [  5.30454066,   8.17987946, 166.64793877, 136.73714054,
#          35.16019601],
#        ...,
#        [  5.66758864,   8.23793708, 138.36236604, 131.91317322,
#          34.08465537],
#        [  7.1607577 ,  11.14711579, 269.00737081, 242.20666102,
#          50.46791571],
#        [  6.33838334,  11.82713341, 291.66729863, 234.09664242,
#          48.11710799]])

# %%
reg.score(X_test,Y_test)
# Out:
# 0.05439255370689107

# %%
reg.predict([[1,2010,2]])
# Out:
# array([[  8.91798378,  12.95283315, 437.54389246, 375.86762375,
#          72.82718147]])

# %%
df
# Out:
#       Area_Name  Year  Group_Name  Victims_Upto_10_15_Yrs  \
# 0             0  2001           0                9.536530
# 1             1  2001           0               15.000000
# 2             2  2001           0                0.000000
# 3             3  2001           0                8.000000
# 4             4  2001           0                0.000000
# ...         ...   ...         ...                     ...
# 1013         28  2010           2               13.000000
# 1014         29  2010           2                2.000000
# 1015         30  2010           2               23.841324
# 1016         31  2010           2                1.000000
# 1017         32  2010           2                8.000000
#
#       Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# 0                  17.326577                   4.000                     3.0
# 1                  41.816441                 269.000                   175.0
# ...

# %%
reg.predict([[32,2010,2]])
# Out:
# array([[  9.41249342,  13.32788331, 383.91261287, 362.35387671,
#          69.61629207]])

# %%
df.describe()
# Out:
#          Area_Name         Year   Group_Name  Victims_Upto_10_15_Yrs  \
# count  1018.000000  1018.000000  1018.000000             1018.000000
# mean     16.898821  2005.512770     1.004912                6.699427
# std      10.161362     2.866127     0.817084                7.349336
# min       0.000000  2001.000000     0.000000                0.000000
# 25%       8.000000  2003.000000     0.000000                0.000000
# 50%      17.000000  2006.000000     1.000000                4.000000
# 75%      26.000000  2008.000000     2.000000                9.536530
# max      34.000000  2010.000000     2.000000               23.841324
#
#        Victims_Upto_15_18_Yrs  Victims_Upto_18_30_Yrs  Victims_Upto_30_50_Yrs  \
# count             1018.000000             1018.000000             1018.000000
# mean                11.189243              266.007273              231.139228
# std                 13.328326              312.640955              261.791364
# ...

# %%
from sklearn.model_selection import train_test_split

train_df, test_df= train_test_split(df, test_size=0.2, random_state=5)
print(train_df.shape)
print(test_df.shape)
# Out:
# (814, 9)
# (204, 9)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score

def print_model_scores(model, data, predictor, target):
    model.fit(data[predictor], data[target])
    predictions=(model.predict(data[predictor]))
    accuracy= accuracy_score(predictions,data[target])
    print('Accuracy:%s' % '{0:.2}'.format(accuracy))
    scores= cross_val_score(model, data[predictor], data[target], 
                            scoring="neg_mean_squared_error",cv=5)
    print('cross-validation Scores: {}'.format(np.sqrt(-scores)))
    print(f'Average RMSE: {np.sqrt(-scores).mean()}')

# %%
target_var=['Victims_Upto_10_15_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs','Victims_Above_50_Yrs','Victims_Total']
predictor_var=['Area_Name','Year','Group_Name']
model = LogisticRegression()

print_model_scores(model, train_df, predictor_var,target_var)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-20a708b725d7> in <module>
#       3 model = LogisticRegression()
#       4
# ----> 5 print_model_scores(model, train_df, predictor_var,target_var)
#
# <ipython-input-106-090939e30a88> in print_model_scores(model, data, predictor, target)
#       5
#       6 def print_model_scores(model, data, predictor, target):
# ----> 7     model.fit(data[predictor], data[target])
#       8     predictions=(model.predict(data[predictor]))
#       9     accuracy= accuracy_score(predictions,data[target])
#
# c:\users\gk\appdata\local\programs\python\python39\lib\site-packages\sklearn\linear_model\_logistic.py in fit(self, X, y, sample_weight)
#    1345                                    order="C",
#    1346                                    accept_large_sparse=solver != 'liblinear')
# ...

# %%
target_var=['Victims_Upto_10_15_Yrs','Victims_Upto_15_18_Yrs','Victims_Upto_18_30_Yrs','Victims_Upto_30_50_Yrs','Victims_Above_50_Yrs','Victims_Total']
predictor_var=['Area_Name','Year','Group_Name']
model= RandomForestClassifier(n_estimators=100)
print_model_scores(model, train_df, predictor_var,target_var)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-a683b3504d59> in <module>
#       2 predictor_var=['Area_Name','Year','Group_Name']
#       3 model= RandomForestClassifier(n_estimators=100)
# ----> 4 print_model_scores(model, train_df, predictor_var,target_var)
#
# <ipython-input-99-630dd89b705b> in print_model_scores(model, data, predictor, target)
#       4
#       5 def print_model_scores(model, data, predictor, target):
# ----> 6     model.fit(data[predictor], data[target])
#       7     predictions=(model.predict(data[predictor]))
#       8     accuracy= accuracy_score(predictions,data[target])
#
# c:\users\gk\appdata\local\programs\python\python39\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     329         self.n_outputs_ = y.shape[1]
#     330
# ...
